# %%
# !pip install pandas

# %%
import pandas as pd

# %%
pd.read_csv("D:\\batchs\\2023\\cvs .file\\dirtydata.csv")
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'  110.0       130     409.1
# 1         60  '2020/12/02'  117.0       145     479.0
# 2         60  '2020/12/03'  103.0       135     340.0
# 3         45  '2020/12/04'  109.0       175     282.4
# 4         45  '2020/12/05'  117.0       148     406.0
# 5         60  '2020/12/06'  102.0       127     300.0
# 6         60  '2020/12/07'  110.0       136     374.0
# 7        450  '2020/12/08'  104.0       134     253.3
# 8         30  '2020/12/09'  109.0       133     195.1
# 9         60  '2020/12/10'   98.0       124     269.0
# 10        60  '2020/12/11'  103.0       147     329.3
# 11        60  '2020/12/12'  100.0       120     250.7
# 12        60  '2020/12/12'  100.0       120     250.7
# 13        60  '2020/12/13'    NaN       128     345.3
# 14        60  '2020/12/14'  104.0       132     379.3
# 15        60  '2020/12/15'   98.0       123     275.0
# ...

# %%
df = pd.read_csv("D:\\batchs\\2023\\cvs .file\\dirtydata.csv")

# %%
df
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'  110.0       130     409.1
# 1         60  '2020/12/02'  117.0       145     479.0
# 2         60  '2020/12/03'  103.0       135     340.0
# 3         45  '2020/12/04'  109.0       175     282.4
# 4         45  '2020/12/05'  117.0       148     406.0
# 5         60  '2020/12/06'  102.0       127     300.0
# 6         60  '2020/12/07'  110.0       136     374.0
# 7        450  '2020/12/08'  104.0       134     253.3
# 8         30  '2020/12/09'  109.0       133     195.1
# 9         60  '2020/12/10'   98.0       124     269.0
# 10        60  '2020/12/11'  103.0       147     329.3
# 11        60  '2020/12/12'  100.0       120     250.7
# 12        60  '2020/12/12'  100.0       120     250.7
# 13        60  '2020/12/13'    NaN       128     345.3
# 14        60  '2020/12/14'  104.0       132     379.3
# 15        60  '2020/12/15'   98.0       123     275.0
# ...

# %%
df.head(4)
# Out:
#    Duration          Date  Pulse  Maxpulse  Calories
# 0        60  '2020/12/01'  110.0       130     409.1
# 1        60  '2020/12/02'  117.0       145     479.0
# 2        60  '2020/12/03'  103.0       135     340.0
# 3        45  '2020/12/04'  109.0       175     282.4

# %%
df.tail(4)
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 28        60  '2020/12/28'  103.0       132       NaN
# 29        60  '2020/12/29'  100.0       132     280.0
# 30        60  '2020/12/30'  102.0       129     380.3
# 31        60  '2020/12/31'   92.0       115     243.0

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
pd.read_csv("D:\\batchs\\2023\\cvs .file\\dirtydata.csv",header = None)
# Out:
#            0             1      2         3         4
# 0   Duration          Date  Pulse  Maxpulse  Calories
# 1         60  '2020/12/01'    110       130     409.1
# 2         60  '2020/12/02'    117       145       479
# 3         60  '2020/12/03'    103       135       340
# 4         45  '2020/12/04'    109       175     282.4
# 5         45  '2020/12/05'    117       148       406
# 6         60  '2020/12/06'    102       127       300
# 7         60  '2020/12/07'    110       136       374
# 8        450  '2020/12/08'    104       134     253.3
# 9         30  '2020/12/09'    109       133     195.1
# 10        60  '2020/12/10'     98       124       269
# 11        60  '2020/12/11'    103       147     329.3
# 12        60  '2020/12/12'    100       120     250.7
# 13        60  '2020/12/12'    100       120     250.7
# 14        60  '2020/12/13'    NaN       128     345.3
# 15        60  '2020/12/14'    104       132     379.3
# ...

# %%
df.columns
# Out:
# Index(['Duration', 'Date', 'Pulse', 'Maxpulse', 'Calories'], dtype='object')

# %%
df["Duration"]
# Out:
# 0      60
# 1      60
# 2      60
# 3      45
# 4      45
# 5      60
# 6      60
# 7     450
# 8      30
# 9      60
# 10     60
# 11     60
# 12     60
# 13     60
# 14     60
# 15     60
# 16     60
# 17     60
# 18     45
# 19     60
# 20     45
# 21     60
# 22     45
# 23     60
# 24     45
# 25     60
# 26     60
# 27     60
# 28     60
# 29     60
# 30     60
# 31     60
# Name: Duration, dtype: int64

# %%
type(df["Duration"])
# Out:
# pandas.core.series.Series

# %%
df.dtypes
# Out:
# Duration      int64
# Date         object
# Pulse       float64
# Maxpulse      int64
# Calories    float64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Duration  32 non-null     int64
#  1   Date      31 non-null     object
#  2   Pulse     31 non-null     float64
#  3   Maxpulse  32 non-null     int64
#  4   Calories  30 non-null     float64
# dtypes: float64(2), int64(2), object(1)
# memory usage: 1.4+ KB

# %%
df.describe()
# Out:
#          Duration       Pulse    Maxpulse    Calories
# count   32.000000   31.000000   32.000000   30.000000
# mean    68.437500  103.419355  128.500000  304.680000
# std     70.039591    7.948896   12.998759   66.003779
# min     30.000000   90.000000  101.000000  195.100000
# 25%     60.000000  100.000000  120.000000  250.700000
# 50%     60.000000  102.000000  127.500000  291.200000
# 75%     60.000000  106.500000  132.250000  343.975000
# max    450.000000  130.000000  175.000000  479.000000

# %%
df.dtypes == "object"
# Out:
# Duration    False
# Date         True
# Pulse       False
# Maxpulse    False
# Calories    False
# dtype: bool

# %%
df[df.dtypes[df.dtypes == "object"].index].describe()
# Out:
#                 Date
# count             31
# unique            30
# top     '2020/12/12'
# freq               2

# %%
 df["Duration"][1:6]
# Out:
# 1    60
# 2    60
# 3    45
# 4    45
# 5    60
# Name: Duration, dtype: int64

# %%
 df["Duration"][1:9:2]
# Out:
# 1     60
# 3     45
# 5     60
# 7    450
# Name: Duration, dtype: int64

# %%
df.isnull()
# Out:
#     Duration   Date  Pulse  Maxpulse  Calories
# 0      False  False  False     False     False
# 1      False  False  False     False     False
# 2      False  False  False     False     False
# 3      False  False  False     False     False
# 4      False  False  False     False     False
# 5      False  False  False     False     False
# 6      False  False  False     False     False
# 7      False  False  False     False     False
# 8      False  False  False     False     False
# 9      False  False  False     False     False
# 10     False  False  False     False     False
# 11     False  False  False     False     False
# 12     False  False  False     False     False
# 13     False  False   True     False     False
# 14     False  False  False     False     False
# 15     False  False  False     False     False
# 16     False  False  False     False     False
# 17     False  False  False     False     False
# 18     False  False  False     False      True
# ...

# %%
df.isnull().sum()
# Out:
# Duration    0
# Date        1
# Pulse       1
# Maxpulse    0
# Calories    2
# dtype: int64

# %%
df.shape
# Out:
# (32, 5)

# %%
df["Duration"].isnull().head()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# Name: Duration, dtype: bool

# %%
df.head()["Date"]=="2020"
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# Name: Date, dtype: bool

# %%
date = pd.to_datetime(df["Date"])

# %%
date[1:5]
# Out:
# 1   2020-12-02
# 2   2020-12-03
# 3   2020-12-04
# 4   2020-12-05
# Name: Date, dtype: datetime64[ns]

# %%
type(date)
# Out:
# pandas.core.series.Series

# %%
df["converted_Date"]=pd.to_datetime(df["Date"])

# %%
df
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories converted_Date
# 0         60  '2020/12/01'  110.0       130     409.1     2020-12-01
# 1         60  '2020/12/02'  117.0       145     479.0     2020-12-02
# 2         60  '2020/12/03'  103.0       135     340.0     2020-12-03
# 3         45  '2020/12/04'  109.0       175     282.4     2020-12-04
# 4         45  '2020/12/05'  117.0       148     406.0     2020-12-05
# 5         60  '2020/12/06'  102.0       127     300.0     2020-12-06
# 6         60  '2020/12/07'  110.0       136     374.0     2020-12-07
# 7        450  '2020/12/08'  104.0       134     253.3     2020-12-08
# 8         30  '2020/12/09'  109.0       133     195.1     2020-12-09
# 9         60  '2020/12/10'   98.0       124     269.0     2020-12-10
# 10        60  '2020/12/11'  103.0       147     329.3     2020-12-11
# 11        60  '2020/12/12'  100.0       120     250.7     2020-12-12
# 12        60  '2020/12/12'  100.0       120     250.7     2020-12-12
# ...

# %%
df.head()
# Out:
#    Duration          Date  Pulse  Maxpulse  Calories converted_Date
# 0        60  '2020/12/01'  110.0       130     409.1     2020-12-01
# 1        60  '2020/12/02'  117.0       145     479.0     2020-12-02
# 2        60  '2020/12/03'  103.0       135     340.0     2020-12-03
# 3        45  '2020/12/04'  109.0       175     282.4     2020-12-04
# 4        45  '2020/12/05'  117.0       148     406.0     2020-12-05

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Duration        32 non-null     int64
#  1   Date            31 non-null     object
#  2   Pulse           31 non-null     float64
#  3   Maxpulse        32 non-null     int64
#  4   Calories        30 non-null     float64
#  5   converted_Date  31 non-null     datetime64[ns]
# dtypes: datetime64[ns](1), float64(2), int64(2), object(1)
# memory usage: 1.6+ KB

# %%
df["date_year"]=df["converted_Date"].dt.year

# %%
df.head()
# Out:
#    Duration          Date  Pulse  Maxpulse  Calories converted_Date  date_year
# 0        60  '2020/12/01'  110.0       130     409.1     2020-12-01     2020.0
# 1        60  '2020/12/02'  117.0       145     479.0     2020-12-02     2020.0
# 2        60  '2020/12/03'  103.0       135     340.0     2020-12-03     2020.0
# 3        45  '2020/12/04'  109.0       175     282.4     2020-12-04     2020.0
# 4        45  '2020/12/05'  117.0       148     406.0     2020-12-05     2020.0

# %%
df.tail()
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories converted_Date  \
# 27        60  '2020/12/27'   92.0       118     241.0     2020-12-27
# 28        60  '2020/12/28'  103.0       132       NaN     2020-12-28
# 29        60  '2020/12/29'  100.0       132     280.0     2020-12-29
# 30        60  '2020/12/30'  102.0       129     380.3     2020-12-30
# 31        60  '2020/12/31'   92.0       115     243.0     2020-12-31
#
#     date_year
# 27     2020.0
# 28     2020.0
# 29     2020.0
# 30     2020.0
# 31     2020.0

# %%
df["month"]=df["converted_Date"].dt.month

# %%
df.head()
# Out:
#    Duration          Date  Pulse  Maxpulse  Calories converted_Date  \
# 0        60  '2020/12/01'  110.0       130     409.1     2020-12-01
# 1        60  '2020/12/02'  117.0       145     479.0     2020-12-02
# 2        60  '2020/12/03'  103.0       135     340.0     2020-12-03
# 3        45  '2020/12/04'  109.0       175     282.4     2020-12-04
# 4        45  '2020/12/05'  117.0       148     406.0     2020-12-05
#
#    date_year  month
# 0     2020.0   12.0
# 1     2020.0   12.0
# 2     2020.0   12.0
# 3     2020.0   12.0
# 4     2020.0   12.0

# %%
df["week"]=df["converted_Date"].dt.week
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_9816\2099111935.py:1: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated. Please use Series.dt.isocalendar().week instead.
#   df["week"]=df["converted_Date"].dt.week

# %%
df.tail()
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories converted_Date  \
# 27        60  '2020/12/27'   92.0       118     241.0     2020-12-27
# 28        60  '2020/12/28'  103.0       132       NaN     2020-12-28
# 29        60  '2020/12/29'  100.0       132     280.0     2020-12-29
# 30        60  '2020/12/30'  102.0       129     380.3     2020-12-30
# 31        60  '2020/12/31'   92.0       115     243.0     2020-12-31
#
#     date_year  month  week
# 27     2020.0   12.0  52.0
# 28     2020.0   12.0  53.0
# 29     2020.0   12.0  53.0
# 30     2020.0   12.0  53.0
# 31     2020.0   12.0  53.0

# %%
df["month"].value_counts()
# Out:
# 12.0    31
# Name: month, dtype: int64

# %%
df["week"].value_counts()
# Out:
# 50.0    8
# 51.0    7
# 49.0    6
# 52.0    6
# 53.0    4
# Name: week, dtype: int64

# %%
df.groupby("date_year")["Pulse"].mean()
# Out:
# date_year
# 2020.0    103.533333
# Name: Pulse, dtype: float64

# %%
df.groupby("date_year")["Pulse"].sum()
# Out:
# date_year
# 2020.0    3106.0
# Name: Pulse, dtype: float64

# %%
df["new"]=df["month"]+df["week"]

# %%
df.head()
# Out:
#    Duration          Date  Pulse  Maxpulse  Calories converted_Date  \
# 0        60  '2020/12/01'  110.0       130     409.1     2020-12-01
# 1        60  '2020/12/02'  117.0       145     479.0     2020-12-02
# 2        60  '2020/12/03'  103.0       135     340.0     2020-12-03
# 3        45  '2020/12/04'  109.0       175     282.4     2020-12-04
# 4        45  '2020/12/05'  117.0       148     406.0     2020-12-05
#
#    date_year  month  week   new
# 0     2020.0   12.0  49.0  61.0
# 1     2020.0   12.0  49.0  61.0
# 2     2020.0   12.0  49.0  61.0
# 3     2020.0   12.0  49.0  61.0
# 4     2020.0   12.0  49.0  61.0

# %%
df.drop("new",axis=1,inplace=True)

# %%
df
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories converted_Date  \
# 0         60  '2020/12/01'  110.0       130     409.1     2020-12-01
# 1         60  '2020/12/02'  117.0       145     479.0     2020-12-02
# 2         60  '2020/12/03'  103.0       135     340.0     2020-12-03
# 3         45  '2020/12/04'  109.0       175     282.4     2020-12-04
# 4         45  '2020/12/05'  117.0       148     406.0     2020-12-05
# 5         60  '2020/12/06'  102.0       127     300.0     2020-12-06
# 6         60  '2020/12/07'  110.0       136     374.0     2020-12-07
# 7        450  '2020/12/08'  104.0       134     253.3     2020-12-08
# 8         30  '2020/12/09'  109.0       133     195.1     2020-12-09
# 9         60  '2020/12/10'   98.0       124     269.0     2020-12-10
# 10        60  '2020/12/11'  103.0       147     329.3     2020-12-11
# 11        60  '2020/12/12'  100.0       120     250.7     2020-12-12
# 12        60  '2020/12/12'  100.0       120     250.7     2020-12-12
# ...

# %%
df.head()
# Out:
#    Duration          Date  Pulse  Maxpulse  Calories converted_Date  \
# 0        60  '2020/12/01'  110.0       130     409.1     2020-12-01
# 1        60  '2020/12/02'  117.0       145     479.0     2020-12-02
# 2        60  '2020/12/03'  103.0       135     340.0     2020-12-03
# 3        45  '2020/12/04'  109.0       175     282.4     2020-12-04
# 4        45  '2020/12/05'  117.0       148     406.0     2020-12-05
#
#    date_year  month  week
# 0     2020.0   12.0  49.0
# 1     2020.0   12.0  49.0
# 2     2020.0   12.0  49.0
# 3     2020.0   12.0  49.0
# 4     2020.0   12.0  49.0

# %%
df.drop(1)
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories converted_Date  \
# 0         60  '2020/12/01'  110.0       130     409.1     2020-12-01
# 2         60  '2020/12/03'  103.0       135     340.0     2020-12-03
# 3         45  '2020/12/04'  109.0       175     282.4     2020-12-04
# 4         45  '2020/12/05'  117.0       148     406.0     2020-12-05
# 5         60  '2020/12/06'  102.0       127     300.0     2020-12-06
# 6         60  '2020/12/07'  110.0       136     374.0     2020-12-07
# 7        450  '2020/12/08'  104.0       134     253.3     2020-12-08
# 8         30  '2020/12/09'  109.0       133     195.1     2020-12-09
# 9         60  '2020/12/10'   98.0       124     269.0     2020-12-10
# 10        60  '2020/12/11'  103.0       147     329.3     2020-12-11
# 11        60  '2020/12/12'  100.0       120     250.7     2020-12-12
# 12        60  '2020/12/12'  100.0       120     250.7     2020-12-12
# 13        60  '2020/12/13'    NaN       128     345.3     2020-12-13
# ...

# %%
df.loc[[1,3]]
# Out:
#    Duration          Date  Pulse  Maxpulse  Calories converted_Date  \
# 1        60  '2020/12/02'  117.0       145     479.0     2020-12-02
# 3        45  '2020/12/04'  109.0       175     282.4     2020-12-04
#
#    date_year  month  week
# 1     2020.0   12.0  49.0
# 3     2020.0   12.0  49.0

# %%
df.loc[[1,6]]
# Out:
#    Duration          Date  Pulse  Maxpulse  Calories converted_Date  \
# 1        60  '2020/12/02'  117.0       145     479.0     2020-12-02
# 6        60  '2020/12/07'  110.0       136     374.0     2020-12-07
#
#    date_year  month  week
# 1     2020.0   12.0  49.0
# 6     2020.0   12.0  50.0

# %%
df.iloc[0:4,0:3]
# Out:
#    Duration          Date  Pulse
# 0        60  '2020/12/01'  110.0
# 1        60  '2020/12/02'  117.0
# 2        60  '2020/12/03'  103.0
# 3        45  '2020/12/04'  109.0

# %%
df.isnull().sum()
# Out:
# Duration          0
# Date              1
# Pulse             1
# Maxpulse          0
# Calories          2
# converted_Date    1
# date_year         1
# month             1
# week              1
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# Duration          0
# Date              0
# Pulse             0
# Maxpulse          0
# Calories          0
# converted_Date    0
# date_year         0
# month             0
# week              0
# dtype: int64

# %%
df.dropna(thresh=4,inplace=True)

# %%
df.isnull().sum()
# Out:
# Duration          0
# Date              0
# Pulse             0
# Maxpulse          0
# Calories          0
# converted_Date    0
# date_year         0
# month             0
# week              0
# dtype: int64

# %%
df.fillna(value=4).tail()
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories converted_Date  \
# 26        60      20201226  100.0       120     250.0     2020-12-26
# 27        60  '2020/12/27'   92.0       118     241.0     2020-12-27
# 29        60  '2020/12/29'  100.0       132     280.0     2020-12-29
# 30        60  '2020/12/30'  102.0       129     380.3     2020-12-30
# 31        60  '2020/12/31'   92.0       115     243.0     2020-12-31
#
#     date_year  month  week
# 26     2020.0   12.0  52.0
# 27     2020.0   12.0  52.0
# 29     2020.0   12.0  53.0
# 30     2020.0   12.0  53.0
# 31     2020.0   12.0  53.0

# %%
df["Calories"].unique()
# Out:
# array([409.1, 479. , 340. , 282.4, 406. , 300. , 374. , 253.3, 195.1,
#        269. , 329.3, 250.7, 379.3, 275. , 215.2, 323. , 243. , 364.2,
#        246. , 334.5, 250. , 241. , 280. , 380.3])

# %%
df["Date"].unique()
# Out:
# array(["'2020/12/01'", "'2020/12/02'", "'2020/12/03'", "'2020/12/04'",
#        "'2020/12/05'", "'2020/12/06'", "'2020/12/07'", "'2020/12/08'",
#        "'2020/12/09'", "'2020/12/10'", "'2020/12/11'", "'2020/12/12'",
#        "'2020/12/14'", "'2020/12/15'", "'2020/12/16'", "'2020/12/17'",
#        "'2020/12/19'", "'2020/12/20'", "'2020/12/21'", "'2020/12/23'",
#        "'2020/12/24'", "'2020/12/25'", '20201226', "'2020/12/27'",
#        "'2020/12/29'", "'2020/12/30'", "'2020/12/31'"], dtype=object)
